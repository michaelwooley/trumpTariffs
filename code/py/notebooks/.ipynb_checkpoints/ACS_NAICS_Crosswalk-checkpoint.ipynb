# %% [markdown]
# # Industry Classifications and Crosswalks
#
# Although ACS supposedly has an NAICS industry variable, it doesn't gel with the summary-level industries provided in the IO Tables from the BEA.
#
# This notebook discusses how these differences were reconciled.

# %% [markdown]
# #### Computer-Specific Code Setup
#
# Following lines should be run once. You may need to change this if you're not running this on MW's machine.

# %%
# May need to reset working directory
# Used for relative paths below
import os 
wkdir = '/home/michael/Dropbox/grantThornton/projects/tariffsTrump/code/py'
os.chdir(wkdir)

# %%
import pandas as pd
import numpy as np
import re,warnings

from src.IpumsExtract import IpumsExtract

# %% [markdown]
# ## Sorting through the ACS classification

# %%
NAICS_FILE = '../data/raw/naics_codes_ipums.xlsx'
NAICS_SHEET = 'data'

acs = pd.read_excel(NAICS_FILE, sheetname=NAICS_SHEET)
acs.rename(
columns={
  'INDNAICS CODE\n(2003-onward ACS/PRCS)': 'ind',
  '2012 NAICS EQUIVALENT': 'naics',
  'INDUSTRY TITLE': 'desc'
},
inplace=True
)
acs = acs[['ind', 'naics', 'desc']]

acs.dropna(how='all', axis=0, inplace=True)
acs.fillna(method='ffill', inplace=True)

# %% [markdown]
# Here's a look at the data:

# %%
acs
# Out:
#                                                    ind  \
# 1                                                    0
# 3                                                  111
# 4                                                  112
# 5                                                  112
# 6                                                 113M
# 7                                                 1133
# 8                                                  114
# 9                                                  115
# 11                                                 211
# 12                                                2121
# 13                                                2122
# 14                                                2123
# 15                                                 21S
# 16                                                 213
# 18                                               2211P
# 19                                               2212P
# ...

# %% [markdown]
# We will:
#
#
# - In the `ind` variable:
#     - Drop at `ind`=0 because these people are not in the ACS dataset or the IO table.
#     - Drop cases outside of 2013- (`'51M (2003-2007)'`)
#     - Reformat cases: `'3231 (2008-onward)'`
#     - Reformat all to strings
#     - Remove hidden characters from strings (`\n`)
# - Deal with several mapping cases:
#      - Direct: e.g. `213 => 213`
#      - Multiple: e.g. `213 => 213, 213s`
#      - "Part of": e.g. `213 => Part of 21`
#      - All except: e.g. `3118Z	=> 3118 exc. 311811` or `928P => '928 (exc. 928110)'` or `3329 exc. 332992-332995`
#      - Combinations of above: e.g. `221MP =>	Pts. 2211, 2212`

# %% [markdown]
# #### `ind` Variable Reformatting

# %%
# Get rid of unemployed/NA
acs = acs.loc[acs['naics'] != '-'].copy()

# Convert all to strings
acs['ind'] = acs['ind'].apply(str)

# %% [markdown]
# Now go to _discontinued series_. All of these discontinued series were replaced by others with the same mapping.

# %%
# Discontinued series
discon = [ind for ind in acs['ind'] if re.match('(.*)([\\n]?)\(2003\-20[107824]\)',ind) is None]
# discon = [ind for ind in discon if re.match('(.*)\(2003\-2007\)',ind) is None]

acs = acs.loc[acs['ind'].isin(discon)]

# %%
acs['ind'] = acs['ind'].apply(lambda d: re.sub('(.*)(\s+)(\(20[05813]+\-onward\))', '\\1', d))

# %% [markdown]
# Now we need to handle the special case of 8114. We will re-code this manually:

# %%
acs.loc[acs['ind'] == '8114Z (8114 in 2005-onward. Incl. 81143 in 2005-onward.)', ['ind', 'naics']] = ['8114', '8114, 81143']

# %%
acs = acs.loc[acs['ind'] != '81143 (pt. of 8114 in 2005-onward.)'].copy()

# %% [markdown]
# _Check._
#
# Now we need to double-check that all of the industries found in the ACS data are also found in the cross-walk.

# %%
# Initiate IpumsExtract Object
ie = IpumsExtract(
  '../data/raw/usa_00022.dat.gz',
  '../data/raw/usa_00022.do',
  db_filename='../data/int/acs_2016.db'
)

# Get the number of workers in each county-industry
script = """
SELECT DISTINCT indnaics as ind
FROM
  main
;
"""

check = ie.read_sql(script)

# %%
test = all([cind in acs['ind'].values for cind in check.values])
if not test:
    not_in_acs = list([cind for cind in check.values if (cind not in acs['ind'].values)][0])
    warnings.warn('Industries not found in ACS: {}'.format(not_in_acs))
# Out:
# /home/michael/anaconda3/lib/python3.6/site-packages/ipykernel_launcher.py:4: UserWarning: Industries not found in ACS: ['333MS']
#   after removing the cwd from sys.path.

# %% [markdown]
# It appears that one industry is missing. After looking at the source data it is clear that `333MS` is not in the original crosswalk data.
#
# I will append `333MS` to the `acs` frame and say that it corresponds to the same values as `333M` ('Machinery, n.e.c.').

# %%
acs = (
  acs.append(
    pd.DataFrame(
      [
        {
          'ind': '333MS',
          'naics': '3332, 3334, 3339',
          'desc': 'Machinery, n.e.c.'
        }
      ]
    )
  ).reset_index(drop=True)
)

# %% [markdown]
# #### Duplicate `ind` due to `desc` revision
#
# There are certain cases where there are duplicate industries. From the below, it is clear that this is due to industry renamings (and not different mappings to to the NAICS).
#
# In each case we'll keep the last description.

# %%
dd = acs['ind'].duplicated('last')
acs.loc[dd == True]
# Out:
#                                                   desc    ind  \
# 1                        Animal production (2003-2012)    112
# 26                 Bakeries, except retail (2003-2012)  3118Z
# 37                          Knitting mills (2003-2007)    31M
# 42   Leather tanning and products, except footwear ...   316M
# 45         Paperboard containers and boxes (2003-2012)  32221
# 61   Pottery, ceramics, and related products (2003-...  32711
# 74   Structural metals, and tank and shipping conta...   332M
# 82   Construction mining and oil field machinery (2...  3331M
# 94   Electrical machinery, equipment, and supplies,...   335M
# 106                 Furniture and fixtures (2003-2007)    337
# 109    Toys, amusement, and sporting goods (2003-2007)  3399M
# 113     Motor vehicles, parts and supplies (2003-2007)   4231
# 126          Apparel, fabrics, and notions (2003-2012)   4243
# 189  Publishing, except newspapers and software (20...  5111Z
# ...

# %% [markdown]
# ## Linking to Industries in the IO Tables
#
# As discussed above, the IO Tables follow a different summarization of the full NAICS scheme than the ACS does. As a result, the mapping will not be one-for-one.
#
# After some tinkering I figured that the fastest way to do this would be by hand. There are simply too many quirks in the data to do this easily by code. Almost all of the crossing was easy/straightforward to do by hand, though.

# %%
acs['io_ind'] = [] * len(acs)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-382-583ad6ed93fe> in <module>()
# ----> 1 acs['io_ind'] = [] * len(acs)
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in __setitem__(self, key, value)
#    2329         else:
#    2330             # set column
# -> 2331             self._set_item(key, value)
#    2332
#    2333     def _setitem_slice(self, key, value):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _set_item(self, key, value)
#    2395
#    2396         self._ensure_valid_index(value)
# -> 2397         value = self._sanitize_column(key, value)
#    2398         NDFrame._set_item(self, key, value)
#    2399
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/frame.py in _sanitize_column(self, key, value, broadcast)
#    2566
#    2567             # turn me into an ndarray
# ...

# %%
acs['io_ind'] = [] * len(acs)
acs.loc[acs['ind'] == "111", 'io_ind'] = [
  "1111A0", "1111B0", "111200", "111300", "111400", "111900"
]
acs.loc[acs['ind'] == "112", 'io_ind'] = [
  "1121A0", "112120", "112A00", "112300"
]
acs.loc[acs['ind'] == "113M", 'io_ind'] = [113000]
acs.loc[acs['ind'] == "1133", 'io_ind'] = [113000]
acs.loc[acs['ind'] == "114", 'io_ind'] = [114000]
acs.loc[acs['ind'] == "115", 'io_ind'] = [115000]
acs.loc[acs['ind'] == "211", 'io_ind'] = [211000]
acs.loc[acs['ind'] == "2121", 'io_ind'] = [212100]
acs.loc[acs['ind'] == "2122", 'io_ind'] = ["2122A0", "212230"]
acs.loc[acs['ind'] == "2123", 'io_ind'] = ["212310", "2123A0"]
acs.loc[acs['ind'] == "21S", 'io_ind'] = [
  "211000", "212100", "2122A0", "212230", "212310", "2123A0", "213111",
  "21311A"
]
acs.loc[acs['ind'] == "213", 'io_ind'] = ["213111", "21311A"]
acs.loc[acs['ind'] == "2211P", 'io_ind'] = [221100]
acs.loc[acs['ind'] == "2212P", 'io_ind'] = [221200]
acs.loc[acs['ind'] == "221MP", 'io_ind'] = [221200, 221100, "S00202"]
acs.loc[acs['ind'] == "2213M", 'io_ind'] = [221300]
acs.loc[acs['ind'] == "22132", 'io_ind'] = [221300]
acs.loc[acs['ind'] == "22S", 'io_ind'] = [221200, 221100, 221300]
acs.loc[acs['ind'] == "23", 'io_ind'] = [
  "230301", "230302", "233210", "233230", "233240", "233262", "233293",
  "2332A0", "2332B0", "233411", "233412", "2334A0"
]
acs.loc[acs['ind'] == "311M1", 'io_ind'] = [
  "311111", "311119", "311210", "311221", "31122A", "311225", "311230"
]
acs.loc[acs['ind'] == "3113", 'io_ind'] = [311300]
acs.loc[acs['ind'] == "3114", 'io_ind'] = [311410, 311420]
acs.loc[acs['ind'] == "3115", 'io_ind'] = [
  "31151A", 311513, 311514, 311520
]
acs.loc[acs['ind'] == "3116", 'io_ind'] = ["31161A", 311615]
acs.loc[acs['ind'] == "311811", 'io_ind'] = [311810]
acs.loc[acs['ind'] == "3118Z", 'io_ind'] = ["3118A0"]
acs.loc[acs['ind'] == "311M2", 'io_ind'] = [
  311700, 311910, 311920, 311930, 311940, 311990
]
acs.loc[acs['ind'] == "311S", 'io_ind'] = [
  311111, 311119, 311210, 311221, "31122A", 311225, 311230, 311300, 311410,
  311420, "31151A", 311513, 311514, 311520, "31161A", 311615, 311700, 311810,
  "3118A0", 311910, 311920, 311930, 311940, 311990, 312110, 312120, 312130,
  312140, 312200
]
acs.loc[acs['ind'] == "3121", 'io_ind'] = [312110, 312120, 312130, 312140]
acs.loc[acs['ind'] == "3122", 'io_ind'] = [312200]
acs.loc[acs['ind'] == "3131", 'io_ind'] = [313100]
acs.loc[acs['ind'] == "3132Z", 'io_ind'] = [313200]
acs.loc[acs['ind'] == "3133", 'io_ind'] = [313300]
acs.loc[acs['ind'] == "31411", 'io_ind'] = [314110]
acs.loc[acs['ind'] == "314Z", 'io_ind'] = [314120, 314900]
acs.loc[acs['ind'] == "31M", 'io_ind'] = [313200]
acs.loc[acs['ind'] == "3152", 'io_ind'] = [315000]
acs.loc[acs['ind'] == "3159", 'io_ind'] = [315000]
acs.loc[acs['ind'] == "3162", 'io_ind'] = [316000]
acs.loc[acs['ind'] == "316M", 'io_ind'] = [316000]
acs.loc[acs['ind'] == "3221", 'io_ind'] = [322110, 322120, 322130]
acs.loc[acs['ind'] == "32221", 'io_ind'] = [322210, 322220, 322230, 322291]
acs.loc[acs['ind'] == "3222M", 'io_ind'] = [322299]
acs.loc[acs['ind'] == "323 (2003-2007)", 'io_ind'] = -99
acs.loc[acs['ind'] == "3231", 'io_ind'] = [323110, 323120]
acs.loc[acs['ind'] == "32411", 'io_ind'] = [324110]
acs.loc[acs['ind'] == "3241M", 'io_ind'] = [324121, 324122, 324190]
acs.loc[acs['ind'] == "3252", 'io_ind'] = [325211, "3252A0"]
acs.loc[acs['ind'] == "3253", 'io_ind'] = [325310, 325320]
acs.loc[acs['ind'] == "3254", 'io_ind'] = [325411, 325412, 325413, 325414]
acs.loc[acs['ind'] == "3255", 'io_ind'] = [325510, 325520]
acs.loc[acs['ind'] == "3256", 'io_ind'] = [325610, 325620]
acs.loc[acs['ind'] == "325M", 'io_ind'] = [
  325910, "3259A0", 325110, 325120, 325130, 325180, 325190
]
acs.loc[acs['ind'] == "3261", 'io_ind'] = [
  326110, 326120, 326130, 326140, 326150, 326160, 326190
]
acs.loc[acs['ind'] == "32621", 'io_ind'] = [326210]
acs.loc[acs['ind'] == "3262M", 'io_ind'] = [326220, 326290]
acs.loc[acs['ind'] == "32711", 'io_ind'] = [327100]
acs.loc[acs['ind'] == "32712 (2003-2012)", 'io_ind'] = -99
acs.loc[acs['ind'] == "327120", 'io_ind'] = [327100]
acs.loc[acs['ind'] == "3272", 'io_ind'] = [327200]
acs.loc[acs['ind'] == "327M", 'io_ind'] = [
  327310, 327320, 327330, 327390, 327400
]
acs.loc[acs['ind'] == "3279", 'io_ind'] = [
  327910, 327991, 327992, 327993, 327999
]
acs.loc[acs['ind'] == "331M", 'io_ind'] = [331110, 331200]
acs.loc[acs['ind'] == "3313", 'io_ind'] = ["33131A", "331314", "33131B"]
acs.loc[acs['ind'] == "3314", 'io_ind'] = [331411, 331419, 331420, 331490]
acs.loc[acs['ind'] == "3315", 'io_ind'] = [331510, 331520]
acs.loc[acs['ind'] == "3321", 'io_ind'] = ["33211A", "332114", "33211B"]
acs.loc[acs['ind'] == "3322", 'io_ind'] = [332200]
acs.loc[acs['ind'] == "332M", 'io_ind'] = [
  332310, 332320, 332410, 332420, 332430
]
acs.loc[acs['ind'] == "3327", 'io_ind'] = [332710, 332720]
acs.loc[acs['ind'] == "3328", 'io_ind'] = [332800]
acs.loc[acs['ind'] == "33299M", 'io_ind'] = [
  "332991", "33299A", "332996", "33299B"
]
acs.loc[acs['ind'] == "332MZ", 'io_ind'] = [332500, 332600]
acs.loc[acs['ind'] == "33MS", 'io_ind'] = [
  "33211A", 332114, "33211B", 332200, 332310, 332320, 332410, 332420, 332430,
  332500, 332600, 332710, 332720, 332800, "33291A", 332913, 332991, "33299A",
  332996, "33299B"
]
acs.loc[acs['ind'] == "33311", 'io_ind'] = [333111]
acs.loc[acs['ind'] == "3331M", 'io_ind'] = [333120, 333130]
acs.loc[acs['ind'] == "3333", 'io_ind'] = [
  "33331A", 333313, 333314, 333315
]
acs.loc[acs['ind'] == "3335", 'io_ind'] = [
  333511, "33351A", 333514, "33351B"
]
acs.loc[acs['ind'] == "3336", 'io_ind'] = [333611, 333612, 333613, 333618]
acs.loc[acs['ind'] == "333M", 'io_ind'] = [
  "33329A", 333220, 333295, "33341A", 333414, 333415, "33391A", 333912, 333920,
  "333991", "33399A", 333993, 333994, "33399B"
]
acs.loc[acs['ind'] == "333S", 'io_ind'] = [
  333111, 333112, 333120, 333130, "33329A", 333220, 333295, "33331A", 333313,
  333314, 333315, "33341A", 333414, 333415, 333511, "33351A", 333514, "33351B",
  333611, 333612, 333613, 333618, "33391A", 333912, 333920, 333991, "33399A",
  333993, 333994, "33399B"
]
acs.loc[acs['ind'] == "3341", 'io_ind'] = [334111, 334112, "33411A"]
acs.loc[acs['ind'] == "334M1", 'io_ind'] = [334210, 334220, 334290, 334300]
acs.loc[acs['ind'] == "3345", 'io_ind'] = [
  334510, 334511, 334512, 334513, 334514, 334515, 334516, 334517, "33451A"
]
acs.loc[acs['ind'] == "334M2", 'io_ind'] = [
  "33441A", 334413, 334418, "334610"
]
acs.loc[acs['ind'] == "3352", 'io_ind'] = [
  335210, 335221, 335222, 335224, 335228
]
acs.loc[acs['ind'] == "335M", 'io_ind'] = [
  335110, 335120, 335311, 335312, 335313, 335314, 335911, 335912, 335920,
  335930, 335991, 335999
]
acs.loc[acs['ind'] == "336M", 'io_ind'] = [
  336111, 336112, 336120, 336211, 336212, 336213, 336214, 336310, 336320,
  "3363A0", 336350, 336360, 336370, 336390
]
acs.loc[acs['ind'] == "33641M1", 'io_ind'] = [336411, 336412, 336413]
acs.loc[acs['ind'] == "33641M2", 'io_ind'] = [336414, "33641A"]
acs.loc[acs['ind'] == "3365", 'io_ind'] = [336500]
acs.loc[acs['ind'] == "3366", 'io_ind'] = [336611, 336612]
acs.loc[acs['ind'] == "3369", 'io_ind'] = [336991, 336992, 336999]
acs.loc[acs['ind'] == "3211", 'io_ind'] = [321100]
acs.loc[acs['ind'] == "3212", 'io_ind'] = [321200]
acs.loc[acs['ind'] == "32199M", 'io_ind'] = [321910, "3219A0"]
acs.loc[acs['ind'] == "3219ZM", 'io_ind'] = ["3219A0"]
acs.loc[acs['ind'] == "337", 'io_ind'] = [
  337110, 337121, 337122, "33712A", 337127, "33721A", 337215, 337900
]
acs.loc[acs['ind'] == "3391", 'io_ind'] = [
  339112, 339113, 339114, 339115, 339116
]
acs.loc[acs['ind'] == "3399M", 'io_ind'] = [339920, 339930]
acs.loc[acs['ind'] == "3399ZM", 'io_ind'] = [
  339910, 339940, 339950, 339990
]
acs.loc[acs['ind'] == "3MS", 'io_ind'] = ["321100","321200","321910","3219A0","327100","327200","327310","327320","327330","327390","327400","327910","327991","327992","327993","327999","331110","331200","33131A","331314","33131B","331411","331419","331420","331490","331510","331520","33211A","332114","33211B","332200","332310","332320","332410","332420","332430","332500","332600","332710","332720","332800","33291A","332913","332991","33299A","332996","33299B","333111","333112","333120","333130","33329A","333220","333295","33331A","333313","333314","333315","33341A","333414","333415","333511","33351A","333514","33351B","333611","333612","333613","333618","33391A","333912","333920","333991","33399A","333993","333994","33399B","334111","334112","33411A","334210","334220","334290","334300","33441A","334413","334418","334510","334511","334512","334513","334514","334515","334516","334517","33451A","334610","335110","335120","335210","335221","335222","335224","335228","335311","335312","335313","335314","335911","335912","335920","335930","335991","335999","336111","336112","336120","336211","336212","336213","336214","336310","336320","3363A0","336350","336360","336370","336390","336411","336412","336413","336414","33641A","336500","336611","336612","336991","336992","336999","337110","337121","337122","33712A","337127","33721A","337215","337900","339112","339113","339114","339115","339116","339910","339920","339930","339940","339950","339990","311111","311119","311210","311221","31122A","311225","311230","311300","311410","311420","31151A","311513","311514","311520","31161A","311615","311700","311810","3118A0","311910","311920","311930","311940","311990","312110","312120","312130","312140","312200","313100","313200","313300","314110","314120","314900","315000","316000","322110","322120","322130","322210","322220","322230","322291","322299","323110","323120","324110","324121","324122","324190","325110","325120","325130","325180","325190","325211","3252A0","325310","325320","325411","325412","325413","325414","325510","325520","325610","325620","325910","3259A0","326110","326120","326130","326140","326150","326160","326190","326210","326220","326290"]
acs.loc[acs['ind'] == "4231", 'io_ind'] = [420000]
acs.loc[acs['ind'] == "4232", 'io_ind'] = [420000]
acs.loc[acs['ind'] == "4233", 'io_ind'] = [420000]
acs.loc[acs['ind'] == "4234", 'io_ind'] = [420000]
acs.loc[acs['ind'] == "4235", 'io_ind'] = [420000]
acs.loc[acs['ind'] == "4236", 'io_ind'] = [420000]
acs.loc[acs['ind'] == "4237", 'io_ind'] = [420000]
acs.loc[acs['ind'] == "4238", 'io_ind'] = [420000]
acs.loc[acs['ind'] == "42393", 'io_ind'] = [420000]
acs.loc[acs['ind'] == "4239Z", 'io_ind'] = [420000]
acs.loc[acs['ind'] == "4241", 'io_ind'] = [420000]
acs.loc[acs['ind'] == "424M", 'io_ind'] = [420000]
acs.loc[acs['ind'] == "4243", 'io_ind'] = [420000]
acs.loc[acs['ind'] == "4244", 'io_ind'] = [420000]
acs.loc[acs['ind'] == "4245", 'io_ind'] = [420000]
acs.loc[acs['ind'] == "4247", 'io_ind'] = [420000]
acs.loc[acs['ind'] == "4248", 'io_ind'] = [420000]
acs.loc[acs['ind'] == "42491", 'io_ind'] = [420000]
acs.loc[acs['ind'] == "4249Z", 'io_ind'] = [420000]
acs.loc[acs['ind'] == "4251", 'io_ind'] = [420000]
acs.loc[acs['ind'] == "42S", 'io_ind'] = [420000]
acs.loc[acs['ind'] == "4411", 'io_ind'] = [441000]
acs.loc[acs['ind'] == "4412", 'io_ind'] = [441000]
acs.loc[acs['ind'] == "4413", 'io_ind'] = [441000]
acs.loc[acs['ind'] == "442", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "443111 (2003-2012)", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "443141", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "443142", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "4441Z", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "44413", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "4442", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "4451", 'io_ind'] = [445000]
acs.loc[acs['ind'] == "4452", 'io_ind'] = [445000]
acs.loc[acs['ind'] == "4453", 'io_ind'] = [445000]
acs.loc[acs['ind'] == "44611", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "446Z", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "447", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "448ZM (2003-2007)", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "4481", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "44821", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "4483", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "4511M", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "45113", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "45114", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "45121", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "45211", 'io_ind'] = [452000]
acs.loc[acs['ind'] == "4529", 'io_ind'] = [452000]
acs.loc[acs['ind'] == "4531", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "45321", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "4533", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "45322", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "4539", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "4541 (2003-2004)", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "454111", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "454112", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "454113", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "4542", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "45431 (2003-2012)", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "454310", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "45439", 'io_ind'] = ["4A0000"]
acs.loc[acs['ind'] == "4MS", 'io_ind'] = [441000, 445000, 452000, "4A0000"]
acs.loc[acs['ind'] == "481", 'io_ind'] = [481000]
acs.loc[acs['ind'] == "482", 'io_ind'] = [482000]
acs.loc[acs['ind'] == "483", 'io_ind'] = [483000]
acs.loc[acs['ind'] == "484", 'io_ind'] = [484000]
acs.loc[acs['ind'] == "485M", 'io_ind'] = [485000, "S00201"]
acs.loc[acs['ind'] == "4853", 'io_ind'] = [485000]
acs.loc[acs['ind'] == "486", 'io_ind'] = [486000]
acs.loc[acs['ind'] == "487", 'io_ind'] = ["48A000"]
acs.loc[acs['ind'] == "488", 'io_ind'] = ["48A000"]
acs.loc[acs['ind'] == "491", 'io_ind'] = [491000]
acs.loc[acs['ind'] == "492", 'io_ind'] = [492000]
acs.loc[acs['ind'] == "493", 'io_ind'] = [493000]
acs.loc[acs['ind'] == "51111", 'io_ind'] = [511110]
acs.loc[acs['ind'] == "5111Z", 'io_ind'] = [511120, 511130, "5111A0"]
acs.loc[acs['ind'] == "5112", 'io_ind'] = [511200]
acs.loc[acs['ind'] == "5121", 'io_ind'] = [512100]
acs.loc[acs['ind'] == "5122", 'io_ind'] = [512200]
acs.loc[acs['ind'] == "51M (2003-2007)", 'io_ind'] = -99
acs.loc[acs['ind'] == "515", 'io_ind'] = [515100, 515200]
acs.loc[acs['ind'] == "51913", 'io_ind'] = [519130]
acs.loc[acs['ind'] == "5171", 'io_ind'] = [517110]
acs.loc[acs['ind'] == "517Z", 'io_ind'] = [517210, "517A00"]
acs.loc[acs['ind'] == "5182", 'io_ind'] = [518200]
acs.loc[acs['ind'] == "51912", 'io_ind'] = ["5191A0"]
acs.loc[acs['ind'] == "5191Z (2003-2007)", 'io_ind'] = ["5191A0"]
acs.loc[acs['ind'] == "5191ZM", 'io_ind'] = ["5191A0"]
acs.loc[acs['ind'] == "52M1", 'io_ind'] = ["52A000"]
acs.loc[acs['ind'] == "5221M", 'io_ind'] = ["52A000"]
acs.loc[acs['ind'] == "522M", 'io_ind'] = ["522A00"]
acs.loc[acs['ind'] == "52M2", 'io_ind'] = ["523A00", 523900, 525000]
acs.loc[acs['ind'] == "524", 'io_ind'] = [524100, 524200]
acs.loc[acs['ind'] == "531", 'io_ind'] = ["5310HS", "531ORE"]
acs.loc[acs['ind'] == "5321", 'io_ind'] = [532100]
acs.loc[acs['ind'] == "53223", 'io_ind'] = ["532A00"]
acs.loc[acs['ind'] == "532M", 'io_ind'] = ["532A00"]
acs.loc[acs['ind'] == "53M", 'io_ind'] = [532400]
acs.loc[acs['ind'] == "5411", 'io_ind'] = [541100]
acs.loc[acs['ind'] == "5412", 'io_ind'] = [541200]
acs.loc[acs['ind'] == "5413", 'io_ind'] = [541300]
acs.loc[acs['ind'] == "5414", 'io_ind'] = [541400]
acs.loc[acs['ind'] == "5415", 'io_ind'] = [541511, 541512, "54151A"]
acs.loc[acs['ind'] == "5416", 'io_ind'] = [541610, "5416A0"]
acs.loc[acs['ind'] == "5417", 'io_ind'] = [541700]
acs.loc[acs['ind'] == "5418", 'io_ind'] = [541800]
acs.loc[acs['ind'] == "54194", 'io_ind'] = [541940]
acs.loc[acs['ind'] == "5419Z", 'io_ind'] = ["5419A0", 541920]
acs.loc[acs['ind'] == "55", 'io_ind'] = [550000]
acs.loc[acs['ind'] == "5613", 'io_ind'] = [561300]
acs.loc[acs['ind'] == "5614", 'io_ind'] = [561400]
acs.loc[acs['ind'] == "5615", 'io_ind'] = [561500]
acs.loc[acs['ind'] == "5616", 'io_ind'] = [561600]
acs.loc[acs['ind'] == "5617Z", 'io_ind'] = [561700]
acs.loc[acs['ind'] == "56173", 'io_ind'] = [561700]
acs.loc[acs['ind'] == "561M", 'io_ind'] = [561100, 561200, 561900]
acs.loc[acs['ind'] == "562", 'io_ind'] = [562000]
acs.loc[acs['ind'] == "6111", 'io_ind'] = [611100]
acs.loc[acs['ind'] == "611M1", 'io_ind'] = ["611A00"]
acs.loc[acs['ind'] == "611M2", 'io_ind'] = ["611B00"]
acs.loc[acs['ind'] == "611M3", 'io_ind'] = ["611B00"]
acs.loc[acs['ind'] == "6211", 'io_ind'] = [621100]
acs.loc[acs['ind'] == "6212", 'io_ind'] = [621200]
acs.loc[acs['ind'] == "62131", 'io_ind'] = [621300]
acs.loc[acs['ind'] == "62132", 'io_ind'] = [621300]
acs.loc[acs['ind'] == "6213ZM", 'io_ind'] = [621300]
acs.loc[acs['ind'] == "6214", 'io_ind'] = [621400]
acs.loc[acs['ind'] == "6216", 'io_ind'] = [621600]
acs.loc[acs['ind'] == "621M", 'io_ind'] = [621500, 621900]
acs.loc[acs['ind'] == "622", 'io_ind'] = [622000]
acs.loc[acs['ind'] == "6231", 'io_ind'] = ["623A00"]
acs.loc[acs['ind'] == "623M", 'io_ind'] = ["623B00", "623B00"]
acs.loc[acs['ind'] == "6241", 'io_ind'] = [624100]
acs.loc[acs['ind'] == "6242", 'io_ind'] = ["624A00"]
acs.loc[acs['ind'] == "6243", 'io_ind'] = ["624A00"]
acs.loc[acs['ind'] == "6244", 'io_ind'] = [624400]
acs.loc[acs['ind'] == "711", 'io_ind'] = [711100, 711200, "711A00", 711500]
acs.loc[acs['ind'] == "712", 'io_ind'] = [712000]
acs.loc[acs['ind'] == "71395", 'io_ind'] = [713900]
acs.loc[acs['ind'] == "713Z", 'io_ind'] = [713100, 713200, 713900]
acs.loc[acs['ind'] == "7211", 'io_ind'] = [721000]
acs.loc[acs['ind'] == "721M", 'io_ind'] = [721000]
acs.loc[acs['ind'] == "722Z", 'io_ind'] = [722110, 722211, "722A00"]
acs.loc[acs['ind'] == "7224", 'io_ind'] = ["722A00"]
acs.loc[acs['ind'] == "8111Z", 'io_ind'] = [811100]
acs.loc[acs['ind'] == "811192", 'io_ind'] = [811100]
acs.loc[acs['ind'] == "8112", 'io_ind'] = [811200]
acs.loc[acs['ind'] == "8113", 'io_ind'] = [811300]
acs.loc[acs['ind'] == "8114", 'io_ind'] = [811400]
acs.loc[acs['ind'] == "812111", 'io_ind'] = [812100]
acs.loc[acs['ind'] == "812112", 'io_ind'] = [812100]
acs.loc[acs['ind'] == "8121M", 'io_ind'] = [812100]
acs.loc[acs['ind'] == "8123", 'io_ind'] = [812300]
acs.loc[acs['ind'] == "8122", 'io_ind'] = [812200]
acs.loc[acs['ind'] == "8129", 'io_ind'] = [812900]
acs.loc[acs['ind'] == "8131", 'io_ind'] = [813100]
acs.loc[acs['ind'] == "813M", 'io_ind'] = ["813A00"]
acs.loc[acs['ind'] == "81393", 'io_ind'] = ["813B00"]
acs.loc[acs['ind'] == "8139Z", 'io_ind'] = ["813B00"]
acs.loc[acs['ind'] == "814", 'io_ind'] = [814000]
acs.loc[acs['ind'] == "9211MP", 'io_ind'] = ["S00600"]
acs.loc[acs['ind'] == "92113", 'io_ind'] = ["S00600"]
acs.loc[acs['ind'] == "92119", 'io_ind'] = ["S00600"]
acs.loc[acs['ind'] == "92MP", 'io_ind'] = ["S00600"]
acs.loc[acs['ind'] == "923", 'io_ind'] = ["S00600"]
acs.loc[acs['ind'] == "92M1", 'io_ind'] = ["S00600"]
acs.loc[acs['ind'] == "92M2", 'io_ind'] = ["S00600"]
acs.loc[acs['ind'] == "928P", 'io_ind'] = ["S00500"]
acs.loc[acs['ind'] == "928110P1", 'io_ind'] = ["S00500"]
acs.loc[acs['ind'] == "928110P2", 'io_ind'] = ["S00500"]
acs.loc[acs['ind'] == "928110P3", 'io_ind'] = ["S00500"]
acs.loc[acs['ind'] == "928110P4", 'io_ind'] = ["S00500"]
acs.loc[acs['ind'] == "928110P5", 'io_ind'] = ["S00500"]
acs.loc[acs['ind'] == "928110P6", 'io_ind'] = ["S00500"]
acs.loc[acs['ind'] == "928110P7", 'io_ind'] = ["S00500"]
acs.loc[acs['ind'] == "333MS", 'io_ind'] = [
  "33329A", 333220, 333295, "33341A", 333414, 333415, "33391A", "333912",
  "333920", "333991", "33399A", "333993", "333994", "33399B"
]
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-372-fd66d1050a78> in <module>()
#       1 acs['io_end'] = np.nan
#       2 acs.loc[acs['ind'] == "111", 'io_ind'] = [
# ----> 3   "1111A0", "1111B0", "111200", "111300", "111400", "111900"
#       4 ]
#       5 acs.loc[acs['ind'] == "112", 'io_ind'] = [
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in __setitem__(self, key, value)
#     177             key = com._apply_if_callable(key, self.obj)
#     178         indexer = self._get_setitem_indexer(key)
# --> 179         self._setitem_with_indexer(indexer, value)
#     180
#     181     def _has_valid_type(self, k, axis):
#
# ~/anaconda3/lib/python3.6/site-packages/pandas/core/indexing.py in _setitem_with_indexer(self, indexer, value)
#     339                         new_indexer = convert_from_missing_indexer_tuple(
# ...

# %%
acs['io_ind'] = acs['io_ind'].apply(lambda rr: [str(r) for r in rr])

# %% [markdown]
# ## IO Tables

# %%
io = pd.read_excel(
  '../data/raw/IOUse_After_Redefinitions_PRO_2007_Detail.xlsx',
    sheetname='2007',
  skiprows=3,
  skipfooter=4,
  index_col=0,
  na_values='...'
)

io = io.loc[['Commodity / Industry', 'Code']]
io = io.T.reset_index(drop=True)
io.dropna(how='any', inplace=True)
io.rename(columns={'Commodity / Industry': 'desc', 'Code': 'naics'}, inplace=True)
io['naics'] = io['naics'].apply(str)
io.head()
# Out:
#                                                desc   naics
# 1                                   Oilseed farming  1111A0
# 2                                     Grain farming  1111B0
# 3                       Vegetable and melon farming  111200
# 4                        Fruit and tree nut farming  111300
# 5  Greenhouse, nursery, and floriculture production  111400

# %%
d = ['22131', '22133']

[list(io.loc[io['naics'].apply(lambda dd: dd[:len(di)]) == di, 'naics'].values) for di in d]
# Out:
# [[], []]

# %%
acs2 = acs[['ind', 'naics', 'desc']].copy()
acs2['manual_ind'] = [[]] * len(acs2)
acs2.to_json('../data/int/manual_ind_crosswalk.json', orient='index')

# %%
acs.to_json?

# %%
def replace_intervals(d):
    patt = '([0-9]+)(\-)([0-9]+)'
    mm = re.match(patt, d)
    if mm is not None:
        return re.sub(patt, ', '.join([str(int(ii)) for  ii in range(int(mm[1]), int(mm[3])+1)]), d)
    else:
        return d
